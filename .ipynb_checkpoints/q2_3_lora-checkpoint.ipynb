# %%
import os 
import torch 
import numpy as np 
import pandas as pd 
from datasets import load_dataset
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from peft import get_peft_model, LoraConfig, TaskType
from torch.optim import AdamW
from sklearn.metrics import f1_score, classification_report

print("Imported all libraries!")
# Out:
# Imported all libraries!

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)
# Out:
# Device: cuda

# %%
dataset = load_dataset('surrey-nlp/BESSTIE-CW-26')

train_df = pd.DataFrame(dataset['train'])
val_df   = pd.DataFrame(dataset['validation'])
test_df  = pd.DataFrame(dataset['test'])

train_df['Sarcasm'] = train_df['Sarcasm'].astype(int)
val_df['Sarcasm']   = val_df['Sarcasm'].astype(int)
test_df['Sarcasm']  = test_df['Sarcasm'].astype(int)

train_uk = train_df[train_df['variety'] == 'en-UK']
train_au = train_df[train_df['variety'] == 'en-AU']
train_in = train_df[train_df['variety'] == 'en-IN']

test_uk = test_df[test_df['variety'] == 'en-UK']
test_au = test_df[test_df['variety'] == 'en-AU']
test_in = test_df[test_df['variety'] == 'en-IN']

print("Train sizes - UK:", len(train_uk))
print("Train sizes - AU:", len(train_au))
print("Train sizes - IN:", len(train_in))

print("Test sizes - UK:", len(test_uk))
print("Test sizes - AU:", len(test_au))
print("Test sizes - IN:", len(test_in))
# Out:
# Train sizes - UK: 1203
# Train sizes - AU: 1145
# Train sizes - IN: 1399
# Test sizes - UK: 700
# Test sizes - AU: 667
# Test sizes - IN: 816

# %%
model_name = 'models/qwen2.5-1.5b'
tokenizer = AutoTokenizer.from_pretrained(model_name)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

class SarcasmDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            truncation=True,
            padding='max_length',
            max_length=self.max_len,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].squeeze(),
            'attention_mask': encoding['attention_mask'].squeeze(),
            'label': torch.tensor(self.labels[idx], dtype=torch.long)
        }

print("Tokenizer and dataset class ready")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Tokenizer and dataset class ready

# %%
from peft import get_peft_model, LoraConfig, TaskType

def load_lora_model():
    base_model = AutoModelForSequenceClassification.from_pretrained(
        model_name,
        num_labels=2
    )
    base_model.config.pad_token_id = tokenizer.pad_token_id

    lora_config = LoraConfig(
        task_type=TaskType.SEQ_CLS,
        r=8,
        lora_alpha=16,
        lora_dropout=0.1,
        target_modules=['q_proj', 'v_proj']
    )

    model = get_peft_model(base_model, lora_config)
    model.print_trainable_parameters()
    return model

print("Model loaded!")
# Out:
# Model loaded!

# %%
def train_epoch(model, loader, optimizer, class_weights):
    model.train()
    total_loss = 0
    criterion  = torch.nn.CrossEntropyLoss(weight=class_weights.to(device))

    for batch in loader: 
        input_ids      = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels         = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        loss = criterion(outputs.logits, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(loader)

# %%
def evaluate(model, loader):
    model.eval()
    all_preds  = []
    all_labels = []

    with torch.no_grad():
        for batch in loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            preds = torch.argmax(outputs.logits, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return all_labels, all_preds

# %%
def train_lora_adapter(train_df, variety_name):
    print(f"Training LoRA adapter for {variety_name}...")

    texts = train_df['text'].tolist()
    labels = train_df['Sarcasm'].tolist()

    n_total = len(labels)
    n_neg = labels.count(0)
    n_pos = labels.count(1)
    w0 = n_total / (2 * n_neg)
    w1 = n_total / (2 * n_pos)
    class_weights = torch.tensor([w0, w1], dtype=torch.float)
    print(f"Class weights - Not Sarcastic: {w0:.2f}")
    print(f"Class weights - Sarcastic: {w1:.2f}")

    dataset = SarcasmDataset(texts, labels, tokenizer)
    loader = DataLoader(dataset, batch_size=8, shuffle=True)

    model = load_lora_model()
    model = model.to(device)
    optimizer = AdamW(model.parameters(), lr=2e-4)

    for epoch in range(3):
        loss = train_epoch(model, loader, optimizer, class_weights)
        labels_out, preds_out = evaluate(model, loader)
        f1 = f1_score(labels_out, preds_out, average='macro')
        print(f"Epoch {epoch+1}/3 - Loss: {loss:.4f} - Train F1: {f1:.4f}")

    save_path = f'models/lora_{variety_name.replace("-", "_")}'
    model.save_pretrained(save_path)
    print(f"Adapter saved to {save_path}")

    # clear GPU memory
    del model, optimizer
    torch.cuda.empty_cache()

    return save_path


path_uk = train_lora_adapter(train_uk, 'en-UK')
path_au = train_lora_adapter(train_au, 'en-AU')
path_in = train_lora_adapter(train_in, 'en-IN')
# Out:
# Training LoRA adapter for en-UK...
#   Class weights — Not Sarcastic: 0.54 | Sarcastic: 6.54
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 39
#      34     torch.cuda.empty_cache()
#      36     return save_path
# ---> 39 path_uk = train_lora_adapter(train_uk, 'en-UK')
#      40 path_au = train_lora_adapter(train_au, 'en-AU')
#      41 path_in = train_lora_adapter(train_in, 'en-IN')
#
# Cell In[18], line 18, in train_lora_adapter(train_df, variety_name)
#      15 dataset = SarcasmDataset(texts, labels, tokenizer)
#      16 loader = DataLoader(dataset, batch_size=8, shuffle=True)
# ---> 18 model = load_lora_model()
#      19 model = model.to(device)
#      20 optimizer = AdamW(model.parameters(), lr=2e-4)
#
# Cell In[14], line 4, in load_lora_model()
#       3 def load_lora_model():
# ----> 4     base_model = AutoModelForSequenceClassification.from_pretrained(
#       5         model_name,
#       6         num_labels=2
#       7     )
#       8     base_model.config.pad_token_id = tokenizer.pad_token_id
#      10     lora_config = LoraConfig(
#      11         task_type=TaskType.SEQ_CLS,
#      12         r=8,
#    (...)
#      15         target_modules=['q_proj', 'v_proj']
#      16     )
#
# File /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     568     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     569 )
#
# File /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:3677, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3668     if dtype_orig is not None:
#    3669         torch.set_default_dtype(dtype_orig)
#    3670     (
#    3671         model,
#    3672         missing_keys,
#    3673         unexpected_keys,
#    3674         mismatched_keys,
#    3675         offload_index,
#    3676         error_msgs,
# -> 3677     ) = cls._load_pretrained_model(
#    3678         model,
#    3679         state_dict,
#    3680         loaded_state_dict_keys,  # XXX: rename?
#    3681         resolved_archive_file,
#    3682         pretrained_model_name_or_path,
#    3683         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3684         sharded_metadata=sharded_metadata,
#    3685         _fast_init=_fast_init,
#    3686         low_cpu_mem_usage=low_cpu_mem_usage,
#    3687         device_map=device_map,
#    3688         offload_folder=offload_folder,
#    3689         offload_state_dict=offload_state_dict,
#    3690         dtype=torch_dtype,
#    3691         hf_quantizer=hf_quantizer,
#    3692         keep_in_fp32_modules=keep_in_fp32_modules,
#    3693     )
#    3695 # make sure token embedding weights are still tied if needed
#    3696 model.tie_weights()
#
# File /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:3853, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules)
#    3851 ptrs = collections.defaultdict(list)
#    3852 for name, tensor in model.state_dict().items():
# -> 3853     id_tensor = id_tensor_storage(tensor)
#    3854     ptrs[id_tensor].append(name)
#    3856 # These are all the pointers of shared tensors.
#
# File /usr/local/lib/python3.11/dist-packages/transformers/pytorch_utils.py:294, in id_tensor_storage(tensor)
#     292     unique_id = torch_xla._XLAC._xla_get_tensor_id(tensor)
#     293 else:
# --> 294     unique_id = storage_ptr(tensor)
#     296 return tensor.device, unique_id, storage_size(tensor)
#
# File /usr/local/lib/python3.11/dist-packages/safetensors/torch.py:12, in storage_ptr(tensor)
#       7 import torch
#       9 from safetensors import deserialize, safe_open, serialize, serialize_file
# ---> 12 def storage_ptr(tensor: torch.Tensor) -> int:
#      13     try:
#      14         return tensor.untyped_storage().data_ptr()
#
# KeyboardInterrupt:
